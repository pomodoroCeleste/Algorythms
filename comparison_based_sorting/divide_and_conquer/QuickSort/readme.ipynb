# %% [markdown]
# ### QuickSort Algorithm
#
# QuickSort is a divide-and-conquer algorithm that sorts an array by partitioning it into two subarrays, sorting the subarrays independently, and then combining the results. Here is a step-by-step explanation of how the QuickSort algorithm works:
#
# #### Steps of QuickSort:
#
# 1. **Choose a Pivot**:
#    - Select a pivot element from the array. Common strategies include choosing the first element, the last element, the middle element, or a random element.
#
# 2. **Partition the Array**:
#    - Rearrange the elements in the array so that all elements less than the pivot come before it, and all elements greater than the pivot come after it. The pivot is now in its correct position.
#
# 3. **Recursively Apply QuickSort**:
#    - Recursively apply the same process to the subarrays of elements less than and greater than the pivot.
#
# #### Example:
#
# Consider the array `[10, 7, 8, 9, 1, 5]`.
#
# 1. **Initial List**: `[10, 7, 8, 9, 1, 5]`
# 2. **Choose a Pivot**: Let's choose `5` as the pivot.
# 3. **Partition the Array**:
#    - Rearrange the elements: `[1, 5, 8, 9, 10, 7]`
#    - The pivot `5` is now in its correct position.
# 4. **Recursively Apply QuickSort**:
#    - Apply QuickSort to the subarray `[1]` (elements less than `5`).
#    - Apply QuickSort to the subarray `[8, 9, 10, 7]` (elements greater than `5`).

# %% [markdown]
# #### Time Complexity:
#
# - **Best Case**: O(n log n)
# - **Average Case**: O(n log n)
# - **Worst Case**: O(n^2) (occurs when the pivot is the smallest or largest element)
#
# #### Space Complexity:
#
# - **O(log n)**: Requires additional space for the recursive call stack.
#
# QuickSort is an efficient and widely used sorting algorithm. It is not stable, meaning that it does not preserve the relative order of equal elements. However, it is generally faster in practice compared to other O(n log n) algorithms like Merge Sort.

# %% [markdown]
# ### Partition Algorithm
#
# The Partition algorithm is a key component of the QuickSort algorithm. It rearranges the elements in the array such that all elements less than the pivot come before it, and all elements greater than the pivot come after it. The pivot is then in its correct position. Here is a step-by-step explanation of how the Partition algorithm works:
#
# #### Steps of Partition:
#
# 1. **Choose a Pivot**:
#    - Select a pivot element from the array. Common strategies include choosing the first element, the last element, the middle element, or a random element.
#
# 2. **Rearrange Elements**:
#    - Rearrange the elements in the array so that all elements less than the pivot come before it, and all elements greater than the pivot come after it.
#
# 3. **Place Pivot**:
#    - Place the pivot in its correct position in the array.
#
# #### Example:
#
# Consider the array `[10, 7, 8, 9, 1, 5]` and choose `5` as the pivot.
#
# 1. **Initial List**: `[10, 7, 8, 9, 1, 5]`
# 2. **Rearrange Elements**:
#    - Compare `10` with `5`, no swap needed.
#    - Compare `7` with `5`, no swap needed.
#    - Compare `8` with `5`, no swap needed.
#    - Compare `9` with `5`, no swap needed.
#    - Compare `1` with `5`, swap `1` with `10` to get `[1, 7, 8, 9, 10, 5]`.
# 3. **Place Pivot**:
#    - Swap `5` with `7` to get `[1, 5, 8, 9, 10, 7]`.
#
# The pivot `5` is now in its correct position.

# %% [markdown]
# #### Time Complexity:
#
# - **Best Case**: O(n)
# - **Average Case**: O(n)
# - **Worst Case**: O(n)
#
# #### Space Complexity:
#
# - **O(1)**: Requires a constant amount of additional space.
#
# The Partition algorithm is efficient and works well with the QuickSort algorithm. It is not a stable sorting algorithm, meaning that it does not preserve the relative order of equal elements. However, it is generally faster in practice compared to other O(n log n) algorithms like Merge Sort.

# %%
from IPython.display import Image, display

# Display the image
display(Image(filename='quickSort.png'))
display(Image(filename='partition.png'))
display(Image(filename='randomQuickSort.png'))
